# %% [markdown]
# # Image processesing with Opencv

# %%
pip install opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.2/39.5 MB 4.8 MB/s eta 0:00:09
#     --------------------------------------- 0.7/39.5 MB 7.2 MB/s eta 0:00:06
#    - -------------------------------------- 1.0/39.5 MB 7.3 MB/s eta 0:00:06
#    - -------------------------------------- 1.5/39.5 MB 8.1 MB/s eta 0:00:05
#    -- ------------------------------------- 2.1/39.5 MB 8.8 MB/s eta 0:00:05
#    -- ------------------------------------- 2.3/39.5 MB 8.4 MB/s eta 0:00:05
#    -- ------------------------------------- 2.4/39.5 MB 7.8 MB/s eta 0:00:05
#    -- ------------------------------------- 2.5/39.5 MB 7.6 MB/s eta 0:00:05
#    -- ------------------------------------- 2.8/39.5 MB 6.9 MB/s eta 0:00:06
#    --- ------------------------------------ 3.0/39.5 MB 6.8 MB/s eta 0:00:06
#    --- ------------------------------------ 3.3/39.5 MB 6.6 MB/s eta 0:00:06
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img=cv2.imread(r'C:\Users\Sai Vamshi\OneDrive\Pictures\Screenshots\Screenshot 2024-07-04 212137.png')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1020, 1919, 3)

# %%
plt.imshow(img) # opencv->B G R and Matplotlib-> R G B

# %%
img
# Out:
# array([[[243, 243, 243],
#         [243, 243, 243],
#         [243, 243, 243],
#         ...,
#         [243, 243, 243],
#         [243, 243, 243],
#         [243, 243, 243]],
#
#        [[243, 243, 243],
#         [243, 243, 243],
#         [243, 243, 243],
#         ...,
#         [243, 243, 243],
#         [243, 243, 243],
#         [243, 243, 243]],
#
#        [[243, 243, 243],
#         [243, 243, 243],
#         [243, 243, 243],
#         ...,
#         [243, 243, 243],
#         [243, 243, 243],
#         [243, 243, 243]],
#
#        ...,
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
# ...

# %%
fix_img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
fix_img
# Out:
# array([[[243, 243, 243],
#         [243, 243, 243],
#         [243, 243, 243],
#         ...,
#         [243, 243, 243],
#         [243, 243, 243],
#         [243, 243, 243]],
#
#        [[243, 243, 243],
#         [243, 243, 243],
#         [243, 243, 243],
#         ...,
#         [243, 243, 243],
#         [243, 243, 243],
#         [243, 243, 243]],
#
#        [[243, 243, 243],
#         [243, 243, 243],
#         [243, 243, 243],
#         ...,
#         [243, 243, 243],
#         [243, 243, 243],
#         [243, 243, 243]],
#
#        ...,
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
# ...

# %%
fix_img.shape
# Out:
# (1020, 1919, 3)

# %%
plt.imshow(fix_img)

# %%
img_gray=cv2.imread(r'C:\Users\Sai Vamshi\OneDrive\Pictures\Screenshots\Screenshot 2024-07-04 212137.png',cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (1020, 1919)

# %%
img_gray
# Out:
# array([[243, 243, 243, ..., 243, 243, 243],
#        [243, 243, 243, ..., 243, 243, 243],
#        [243, 243, 243, ..., 243, 243, 243],
#        ...,
#        [235, 235, 235, ..., 235, 235, 235],
#        [235, 235, 235, ..., 235, 235, 235],
#        [235, 235, 235, ..., 235, 235, 235]], dtype=uint8)

# %%
img_gray.min()
# Out:
# np.uint8(0)

# %%
img_gray.max()
# Out:
# np.uint8(255)

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
plt.imshow(img_gray,cmap='magma')

# %%
plt.imshow(img_gray,cmap='Accent')

# %%
plt.imshow(img)

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (1020, 1919, 3)

# %%
fix_img_1=cv2.resize(fix_img,(500,367))
fix_img_1.shape
# Out:
# (367, 500, 3)

# %%
w_ratio=0.5
h_ratio=0.5

# %%
fix_img_2=cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio)

# %%
fix_img_2
# Out:
# array([[[243, 243, 243],
#         [243, 243, 243],
#         [243, 243, 243],
#         ...,
#         [243, 243, 243],
#         [243, 243, 243],
#         [243, 243, 243]],
#
#        [[243, 243, 243],
#         [243, 243, 243],
#         [243, 243, 243],
#         ...,
#         [243, 243, 243],
#         [243, 243, 243],
#         [243, 243, 243]],
#
#        [[243, 243, 243],
#         [247, 247, 247],
#         [248, 248, 248],
#         ...,
#         [243, 243, 243],
#         [243, 243, 243],
#         [243, 243, 243]],
#
#        ...,
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
# ...

# %%
plt.imshow(fix_img_2)

# %%
img3=cv2.flip(fix_img_2,0)
plt.imshow(img3)

# %%
img3=cv2.flip(fix_img_2,1)
plt.imshow(img3)

# %%
img3=cv2.flip(fix_img_2,3)
plt.imshow(img3)

# %%
cv2.imwrite('new genai image.jpg',img3)
# Out:
# True
